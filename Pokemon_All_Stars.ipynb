# %% [markdown]
# <a href="https://colab.research.google.com/github/DrueStaples/Pokemon_All_Stars/blob/master/Pokemon_All_Stars.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Welcome to another problem solving adventure where you will learn while also building a project! A group of pokemon masters want to setup a tournament where trainers can only use pokemon that are within the top 3 most powerful from every type.  They are having a hard time agreeing what the top 3 are for each, so they hire you to statiscally find the solution! Good Luck!

# %% [markdown]
# ###Import Pandas Library

# %%
import pandas as pd

# %% [markdown]
# ###Upload file into a dataframe
#
# Notice I uploaded a csv and an excel sheet; I just wanted to show you this, but you will only need to work with one file

# %%
#file
file = 'pokemon_data.txt'
file_2 = 'pokemon_data.xlsx'

# %%
#reading csv
read_txt = pd.read_csv(file)
read_exl = pd.read_excel(file_2)

# %%
#place csv witin dataframe
poke_df = pd.DataFrame(read_txt)
poke_df_2 = pd.DataFrame(read_exl)

# %%
#dataframe from csv
poke_df.head()
# Out:
#    #                   Name Type 1  ... Speed  Generation  Legendary
# 0  1              Bulbasaur  Grass  ...    45           1      False
# 1  2                Ivysaur  Grass  ...    60           1      False
# 2  3               Venusaur  Grass  ...    80           1      False
# 3  3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 4  4             Charmander   Fire  ...    65           1      False
#
# [5 rows x 12 columns]

# %%
#dataframe from excel
poke_df_2.head()
# Out:
#    #                   Name Type 1  ... Speed  Generation  Legendary
# 0  1              Bulbasaur  Grass  ...    45           1      False
# 1  2                Ivysaur  Grass  ...    60           1      False
# 2  3               Venusaur  Grass  ...    80           1      False
# 3  3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 4  4             Charmander   Fire  ...    65           1      False
#
# [5 rows x 12 columns]

# %% [markdown]
# ###It's good practice to make a copy of your dataframe. This is because if you were to mess it up pretty bad and couldn't remember how to fix your mistakes, you can always rerun this block and your df will go back to it's original form.

# %%
copy_poke = poke_df_2

# %%
copy_poke.head()
# Out:
#    #                   Name Type 1  ... Speed  Generation  Legendary
# 0  1              Bulbasaur  Grass  ...    45           1      False
# 1  2                Ivysaur  Grass  ...    60           1      False
# 2  3               Venusaur  Grass  ...    80           1      False
# 3  3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 4  4             Charmander   Fire  ...    65           1      False
#
# [5 rows x 12 columns]

# %% [markdown]
# ###Find the type to verigy it is indeed a dataframe

# %%
type(copy_poke)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ###Add a extra column called 'Total' tha adds the colunms 4-9

# %%
copy_poke['Total'] = copy_poke.iloc[:, 4:10].sum(axis=1)

# %%
copy_poke
# Out:
#        #                       Name    Type 1  ... Generation  Legendary  Total
# 0      1                  Bulbasaur     Grass  ...          1      False    318
# 1      2                    Ivysaur     Grass  ...          1      False    405
# 2      3                   Venusaur     Grass  ...          1      False    525
# 3      3      VenusaurMega Venusaur     Grass  ...          1      False    625
# 4      4                 Charmander      Fire  ...          1      False    309
# 5      5                 Charmeleon      Fire  ...          1      False    405
# 6      6                  Charizard      Fire  ...          1      False    534
# 7      6  CharizardMega Charizard X      Fire  ...          1      False    634
# 8      6  CharizardMega Charizard Y      Fire  ...          1      False    634
# 9      7                   Squirtle     Water  ...          1      False    314
# 10     8                  Wartortle     Water  ...          1      False    405
# ...

# %%
type(copy_poke)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ###It's good practice to manually do the math yourself to confirm it's correct

# %%
78 + 92 + 75 + 74 + 63 + 118
# Out:
# 500

# %% [markdown]
# ###Separate the instances based on Type 1

# %%
grass = copy_poke.loc[copy_poke['Type 1'] == 'Grass']

# %%
grass
# Out:
#        #                     Name Type 1  ... Generation  Legendary  Total
# 0      1                Bulbasaur  Grass  ...          1      False    318
# 1      2                  Ivysaur  Grass  ...          1      False    405
# 2      3                 Venusaur  Grass  ...          1      False    525
# 3      3    VenusaurMega Venusaur  Grass  ...          1      False    625
# 48    43                   Oddish  Grass  ...          1      False    320
# 49    44                    Gloom  Grass  ...          1      False    395
# 50    45                Vileplume  Grass  ...          1      False    490
# 75    69               Bellsprout  Grass  ...          1      False    300
# 76    70               Weepinbell  Grass  ...          1      False    390
# 77    71               Victreebel  Grass  ...          1      False    490
# 110  102                Exeggcute  Grass  ...          1      False    325
# ...

# %%
type(grass)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ###Find the pokemon with the top 3 highest totals from each Type 1 and place them in their own dataframe

# %%
grass_elite = grass.sort_values('Total', ascending=False).head(3)
# Out:
#        #                   Name Type 1  ... Generation  Legendary  Total
# 275  254  SceptileMega Sceptile  Grass  ...          3      False    630
# 3      3  VenusaurMega Venusaur  Grass  ...          1      False    625
# 551  492       ShayminSky Forme  Grass  ...          4       True    600
#
# [3 rows x 13 columns]

# %%
grass.shape
# Out:
# (70, 13)

# %%
copy_poke.head(15)
# Out:
#      #                       Name Type 1  ... Generation  Legendary  Total
# 0    1                  Bulbasaur  Grass  ...          1      False    318
# 1    2                    Ivysaur  Grass  ...          1      False    405
# 2    3                   Venusaur  Grass  ...          1      False    525
# 3    3      VenusaurMega Venusaur  Grass  ...          1      False    625
# 4    4                 Charmander   Fire  ...          1      False    309
# 5    5                 Charmeleon   Fire  ...          1      False    405
# 6    6                  Charizard   Fire  ...          1      False    534
# 7    6  CharizardMega Charizard X   Fire  ...          1      False    634
# 8    6  CharizardMega Charizard Y   Fire  ...          1      False    634
# 9    7                   Squirtle  Water  ...          1      False    314
# 10   8                  Wartortle  Water  ...          1      False    405
# ...

# %%
copy_poke.sort_values('Type 1', ascending=True)
# Out:
#        #                     Name Type 1  ... Generation  Legendary  Total
# 600  540                 Sewaddle    Bug  ...          5      False    310
# 136  127                   Pinsir    Bug  ...          1      False    500
# 457  412                    Burmy    Bug  ...          4      False    224
# 132  123                  Scyther    Bug  ...          1      False    500
# 656  595                   Joltik    Bug  ...          5      False    319
# 657  596               Galvantula    Bug  ...          5      False    472
# 288  265                  Wurmple    Bug  ...          3      False    195
# 289  266                  Silcoon    Bug  ...          3      False    205
# 677  616                  Shelmet    Bug  ...          5      False    305
# 232  214  HeracrossMega Heracross    Bug  ...          2      False    600
# 290  267                Beautifly    Bug  ...          3      False    395
# ...

# %%
bug_elite = copy_poke.loc[copy_poke['Type 1'] == 'Bug'].sort_values('Total', ascending=False).head(3)

# %%
bug_elite
# Out:
#        #                     Name Type 1  ... Generation  Legendary  Total
# 232  214  HeracrossMega Heracross    Bug  ...          2      False    600
# 717  649                 Genesect    Bug  ...          5      False    600
# 229  212        ScizorMega Scizor    Bug  ...          2      False    600
#
# [3 rows x 13 columns]

# %%
type(bug_elite), bug_elite.shape
# Out:
# (pandas.core.frame.DataFrame, (3, 13))

# %%
type_1_cp = copy_poke.sort_values('Type 1', ascending=True)

# %%
type_1_cp.describe()
# Out:
#                 #          HP      Attack  ...       Speed  Generation      Total
# count  800.000000  800.000000  800.000000  ...  800.000000   800.00000  800.00000
# mean   362.813750   69.258750   79.001250  ...   68.277500     3.32375  435.10250
# std    208.343798   25.534669   32.457366  ...   29.060474     1.66129  119.96304
# min      1.000000    1.000000    5.000000  ...    5.000000     1.00000  180.00000
# 25%    184.750000   50.000000   55.000000  ...   45.000000     2.00000  330.00000
# 50%    364.500000   65.000000   75.000000  ...   65.000000     3.00000  450.00000
# 75%    539.250000   80.000000  100.000000  ...   90.000000     5.00000  515.00000
# max    721.000000  255.000000  190.000000  ...  180.000000     6.00000  780.00000
#
# [8 rows x 9 columns]

# %%
type(type_1_cp), type(type_1_cp['Type 1'])
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %% [markdown]
# ###Find Unique Values within  a column

# %%
unique_poke = type_1_cp['Type 1'].unique() #unique is a Series method

# %%
unique_poke
# Out:
# array(['Bug', 'Dark', 'Dragon', 'Electric', 'Fairy', 'Fighting', 'Fire',
#        'Flying', 'Ghost', 'Grass', 'Ground', 'Ice', 'Normal', 'Poison',
#        'Psychic', 'Rock', 'Steel', 'Water'], dtype=object)

# %%
ground_elite = copy_poke.loc[copy_poke['Type 1'] == 'Ground'].sort_values('Total', ascending=False).head(3)

# %%
ground_elite
# Out:
#        #                     Name  Type 1  ... Generation  Legendary  Total
# 424  383    GroudonPrimal Groudon  Ground  ...          3       True    770
# 423  383                  Groudon  Ground  ...          3       True    670
# 708  645  LandorusIncarnate Forme  Ground  ...          5       True    600
#
# [3 rows x 13 columns]

# %%
fairy_elite = copy_poke.loc[copy_poke['Type 1'] == 'Fairy'].sort_values('Total', ascending=False).head(3)

# %%
fairy_elite
# Out:
#        #      Name Type 1  Type 2  ...  Speed  Generation  Legendary  Total
# 792  716   Xerneas  Fairy     NaN  ...     99           6       True    680
# 739  671   Florges  Fairy     NaN  ...     75           6      False    552
# 519  468  Togekiss  Fairy  Flying  ...     80           4      False    545
#
# [3 rows x 13 columns]

# %%
normal_elite = copy_poke.loc[copy_poke['Type 1'] == 'Normal'].sort_values('Total', ascending=False).head(3)

# %%
normal_elite
# Out:
#        #       Name  Type 1 Type 2  ...  Speed  Generation  Legendary  Total
# 552  493     Arceus  Normal    NaN  ...    120           4       True    720
# 313  289    Slaking  Normal    NaN  ...    100           3      False    670
# 543  486  Regigigas  Normal    NaN  ...    100           4       True    670
#
# [3 rows x 13 columns]

# %%
unique_poke
# Out:
# array(['Bug', 'Dark', 'Dragon', 'Electric', 'Fairy', 'Fighting', 'Fire',
#        'Flying', 'Ghost', 'Grass', 'Ground', 'Ice', 'Normal', 'Poison',
#        'Psychic', 'Rock', 'Steel', 'Water'], dtype=object)

# %%
rock_elite = copy_poke.loc[copy_poke['Type 1'] == 'Rock'].sort_values('Total', ascending=False).head(3)

# %%
rock_elite
# Out:
#        #                       Name Type 1  ... Generation  Legendary  Total
# 796  719        DiancieMega Diancie   Rock  ...          6       True    700
# 268  248    TyranitarMega Tyranitar   Rock  ...          2      False    700
# 154  142  AerodactylMega Aerodactyl   Rock  ...          1      False    615
#
# [3 rows x 13 columns]

# %%
elite_steel = copy_poke.loc[copy_poke['Type 1'] == 'Steel'].sort_values('Total', ascending=False).head(3)

# %%
elite_steel
# Out:
#        #                     Name Type 1  ... Generation  Legendary  Total
# 413  376  MetagrossMega Metagross  Steel  ...          3      False    700
# 540  483                   Dialga  Steel  ...          4       True    680
# 333  306        AggronMega Aggron  Steel  ...          3      False    630
#
# [3 rows x 13 columns]

# %%
unique_poke
# Out:
# array(['Bug', 'Dark', 'Dragon', 'Electric', 'Fairy', 'Fighting', 'Fire',
#        'Flying', 'Ghost', 'Grass', 'Ground', 'Ice', 'Normal', 'Poison',
#        'Psychic', 'Rock', 'Steel', 'Water'], dtype=object)

# %%
fighting_elite = copy_poke.loc[copy_poke['Type 1'] == 'Fighting'].sort_values('Total', ascending=False).head(10)

# %%
fighting_elite
# Out:
#        #                   Name    Type 1  ... Generation  Legendary  Total
# 498  448    LucarioMega Lucario  Fighting  ...          4      False    625
# 497  448                Lucario  Fighting  ...          4      False    525
# 336  308  MedichamMega Medicham  Fighting  ...          3      False    510
# 681  620               Mienshao  Fighting  ...          5      False    510
# 594  534             Conkeldurr  Fighting  ...          5      False    505
# 74    68                Machamp  Fighting  ...          1      False    505
# 771  701               Hawlucha  Fighting  ...          6      False    500
# 743  675                Pangoro  Fighting  ...          6      False    495
# 321  297               Hariyama  Fighting  ...          3      False    474
# 598  538                  Throh  Fighting  ...          5      False    465
#
# [10 rows x 13 columns]

# %% [markdown]
# ##Notice above we have a tie for the 3rd spot. Here I manually look at each column feature from the total and compare the two instances. In this case Mienshao beats MedichamMega Medicham 4 out of the 6 categories, therefore I will drop THAT pokemon via index number.

# %%
fighting_elite = fighting_elite.drop(336)

# %%
fighting_elite = fighting_elite.head(3)

# %%
fighting_elite
# Out:
#        #                 Name    Type 1  ... Generation  Legendary  Total
# 498  448  LucarioMega Lucario  Fighting  ...          4      False    625
# 497  448              Lucario  Fighting  ...          4      False    525
# 681  620             Mienshao  Fighting  ...          5      False    510
#
# [3 rows x 13 columns]

# %%
unique_poke
# Out:
# array(['Bug', 'Dark', 'Dragon', 'Electric', 'Fairy', 'Fighting', 'Fire',
#        'Flying', 'Ghost', 'Grass', 'Ground', 'Ice', 'Normal', 'Poison',
#        'Psychic', 'Rock', 'Steel', 'Water'], dtype=object)

# %%
ice_elite = copy_poke.loc[copy_poke['Type 1'] == 'Ice'].sort_values('Total', ascending=False).head(3)

# %%
ice_elite
# Out:
#        #               Name Type 1  Type 2  ...  Speed  Generation  Legendary  Total
# 415  378             Regice    Ice     NaN  ...     50           3       True    580
# 397  362  GlalieMega Glalie    Ice     NaN  ...    100           3      False    580
# 156  144           Articuno    Ice  Flying  ...     85           1       True    580
#
# [3 rows x 13 columns]

# %%
elite_flying = copy_poke.loc[copy_poke['Type 1'] == 'Flying'].sort_values('Total', ascending=False).head(3)

# %%
elite_flying
# Out:
#        #                     Name  Type 1  ... Generation  Legendary  Total
# 702  641  TornadusIncarnate Forme  Flying  ...          5       True    580
# 703  641    TornadusTherian Forme  Flying  ...          5       True    580
# 791  715                  Noivern  Flying  ...          6      False    535
#
# [3 rows x 13 columns]

# %%
unique_poke
# Out:
# array(['Bug', 'Dark', 'Dragon', 'Electric', 'Fairy', 'Fighting', 'Fire',
#        'Flying', 'Ghost', 'Grass', 'Ground', 'Ice', 'Normal', 'Poison',
#        'Psychic', 'Rock', 'Steel', 'Water'], dtype=object)

# %%
poison_elite = copy_poke.loc[copy_poke['Type 1'] == 'Poison'].sort_values('Total', ascending=False).head(3)

# %%
poison_elite
# Out:
#        #       Name  Type 1  Type 2  ...  Speed  Generation  Legendary  Total
# 183  169     Crobat  Poison  Flying  ...    130           2      False    535
# 39    34   Nidoking  Poison  Ground  ...     85           1      False    505
# 36    31  Nidoqueen  Poison  Ground  ...     76           1      False    505
#
# [3 rows x 13 columns]

# %%
ghost_elite = copy_poke.loc[copy_poke['Type 1'] == 'Ghost'].sort_values('Total', ascending=False).head(3)

# %%
ghost_elite
# Out:
#        #                   Name Type 1  ... Generation  Legendary  Total
# 545  487   GiratinaOrigin Forme  Ghost  ...          4       True    680
# 544  487  GiratinaAltered Forme  Ghost  ...          4       True    680
# 102   94      GengarMega Gengar  Ghost  ...          1      False    600
#
# [3 rows x 13 columns]

# %%
unique_poke
# Out:
# array(['Bug', 'Dark', 'Dragon', 'Electric', 'Fairy', 'Fighting', 'Fire',
#        'Flying', 'Ghost', 'Grass', 'Ground', 'Ice', 'Normal', 'Poison',
#        'Psychic', 'Rock', 'Steel', 'Water'], dtype=object)

# %%
psychic_elite = copy_poke.loc[copy_poke['Type 1'] == 'Psychic'].sort_values('Total', ascending=False).head()

# %%
psychic_elite
# Out:
#        #                 Name   Type 1  ... Generation  Legendary  Total
# 163  150  MewtwoMega Mewtwo X  Psychic  ...          1       True    780
# 164  150  MewtwoMega Mewtwo Y  Psychic  ...          1       True    780
# 798  720   HoopaHoopa Unbound  Psychic  ...          6       True    680
# 269  249                Lugia  Psychic  ...          2       True    680
# 162  150               Mewtwo  Psychic  ...          1       True    680
#
# [5 rows x 13 columns]

# %%
psychic_elite = psychic_elite.drop([798,269])

# %%
psychic_elite
# Out:
#        #                 Name   Type 1  ... Generation  Legendary  Total
# 163  150  MewtwoMega Mewtwo X  Psychic  ...          1       True    780
# 164  150  MewtwoMega Mewtwo Y  Psychic  ...          1       True    780
# 162  150               Mewtwo  Psychic  ...          1       True    680
#
# [3 rows x 13 columns]

# %%
unique_poke
# Out:
# array(['Bug', 'Dark', 'Dragon', 'Electric', 'Fairy', 'Fighting', 'Fire',
#        'Flying', 'Ghost', 'Grass', 'Ground', 'Ice', 'Normal', 'Poison',
#        'Psychic', 'Rock', 'Steel', 'Water'], dtype=object)

# %%
water_elite = copy_poke.loc[copy_poke['Type 1'] == 'Water'].sort_values('Total', ascending=False).head(3)

# %%
water_elite
# Out:
#        #                 Name Type 1  ... Generation  Legendary  Total
# 422  382  KyogrePrimal Kyogre  Water  ...          3       True    770
# 541  484               Palkia  Water  ...          4       True    680
# 421  382               Kyogre  Water  ...          3       True    670
#
# [3 rows x 13 columns]

# %%
dark_elite = copy_poke.loc[copy_poke['Type 1'] == 'Dark'].sort_values('Total', ascending=False).head(3)

# %%
dark_elite
# Out:
#        #                   Name Type 1  ... Generation  Legendary  Total
# 793  717                Yveltal   Dark  ...          6       True    680
# 248  229  HoundoomMega Houndoom   Dark  ...          2      False    600
# 696  635              Hydreigon   Dark  ...          5      False    600
#
# [3 rows x 13 columns]

# %%
fire_elite = copy_poke.loc[copy_poke['Type 1'] == 'Fire'].sort_values('Total', ascending=False).head(3)

# %%
fire_elite
# Out:
#        #                       Name Type 1  ... Generation  Legendary  Total
# 270  250                      Ho-oh   Fire  ...          2       True    680
# 7      6  CharizardMega Charizard X   Fire  ...          1      False    634
# 8      6  CharizardMega Charizard Y   Fire  ...          1      False    634
#
# [3 rows x 13 columns]

# %%
unique_poke
# Out:
# array(['Bug', 'Dark', 'Dragon', 'Electric', 'Fairy', 'Fighting', 'Fire',
#        'Flying', 'Ghost', 'Grass', 'Ground', 'Ice', 'Normal', 'Poison',
#        'Psychic', 'Rock', 'Steel', 'Water'], dtype=object)

# %%
electric_elite = copy_poke.loc[copy_poke['Type 1'] == 'Electric'].sort_values('Total', ascending=False).head(5)

# %%
electric_elite
# Out:
#        #                      Name    Type 1  ... Generation  Legendary  Total
# 196  181     AmpharosMega Ampharos  Electric  ...          2      False    610
# 705  642    ThundurusTherian Forme  Electric  ...          5       True    580
# 157  145                    Zapdos  Electric  ...          1       True    580
# 704  642  ThundurusIncarnate Forme  Electric  ...          5       True    580
# 262  243                    Raikou  Electric  ...          2       True    580
#
# [5 rows x 13 columns]

# %%
electric_elite = electric_elite.drop([705,704])

# %%
electric_elite
# Out:
#        #                   Name    Type 1  ... Generation  Legendary  Total
# 196  181  AmpharosMega Ampharos  Electric  ...          2      False    610
# 157  145                 Zapdos  Electric  ...          1       True    580
# 262  243                 Raikou  Electric  ...          2       True    580
#
# [3 rows x 13 columns]

# %%
unique_poke
# Out:
# array(['Bug', 'Dark', 'Dragon', 'Electric', 'Fairy', 'Fighting', 'Fire',
#        'Flying', 'Ghost', 'Grass', 'Ground', 'Ice', 'Normal', 'Poison',
#        'Psychic', 'Rock', 'Steel', 'Water'], dtype=object)

# %%
dragon_elite = copy_poke.loc[copy_poke['Type 1'] == 'Dragon'].sort_values('Total', ascending=False).head(7)

# %%
dragon_elite
# Out:
#        #                     Name  Type 1  ... Generation  Legendary  Total
# 426  384    RayquazaMega Rayquaza  Dragon  ...          3       True    780
# 420  381        LatiosMega Latios  Dragon  ...          3       True    700
# 418  380        LatiasMega Latias  Dragon  ...          3       True    700
# 711  646       KyuremBlack Kyurem  Dragon  ...          5       True    700
# 712  646       KyuremWhite Kyurem  Dragon  ...          5       True    700
# 494  445    GarchompMega Garchomp  Dragon  ...          4      False    700
# 409  373  SalamenceMega Salamence  Dragon  ...          3      False    700
#
# [7 rows x 13 columns]

# %%
#418->15

#409->15

# %%
dragon_elite = dragon_elite.drop([420,711,712,494])

# %%
dragon_elite
# Out:
#        #                     Name  Type 1  ... Generation  Legendary  Total
# 426  384    RayquazaMega Rayquaza  Dragon  ...          3       True    780
# 418  380        LatiasMega Latias  Dragon  ...          3       True    700
# 409  373  SalamenceMega Salamence  Dragon  ...          3      False    700
#
# [3 rows x 13 columns]

# %%
grass_elite = copy_poke.loc[copy_poke['Type 1'] == 'Grass'].sort_values('Total', ascending=False).head(3)

# %%
grass_elite
# Out:
#        #                   Name Type 1  ... Generation  Legendary  Total
# 275  254  SceptileMega Sceptile  Grass  ...          3      False    630
# 3      3  VenusaurMega Venusaur  Grass  ...          1      False    625
# 551  492       ShayminSky Forme  Grass  ...          4       True    600
#
# [3 rows x 13 columns]

# %%
unique_poke
# Out:
# array(['Bug', 'Dark', 'Dragon', 'Electric', 'Fairy', 'Fighting', 'Fire',
#        'Flying', 'Ghost', 'Grass', 'Ground', 'Ice', 'Normal', 'Poison',
#        'Psychic', 'Rock', 'Steel', 'Water'], dtype=object)

# %% [markdown]
# ###Concatenate all the dataframes into one single dataframe

# %%
ultimate_showdown = pd.concat([bug_elite, dark_elite, dragon_elite, electric_elite, fairy_elite, fighting_elite, fire_elite, elite_flying, ghost_elite, grass_elite, ground_elite, ice_elite, normal_elite, poison_elite, psychic_elite, rock_elite, elite_steel, water_elite])

# %%
ultimate_showdown
# Out:
#        #                       Name    Type 1  ... Generation  Legendary  Total
# 232  214    HeracrossMega Heracross       Bug  ...          2      False    600
# 717  649                   Genesect       Bug  ...          5      False    600
# 229  212          ScizorMega Scizor       Bug  ...          2      False    600
# 793  717                    Yveltal      Dark  ...          6       True    680
# 248  229      HoundoomMega Houndoom      Dark  ...          2      False    600
# 696  635                  Hydreigon      Dark  ...          5      False    600
# 426  384      RayquazaMega Rayquaza    Dragon  ...          3       True    780
# 418  380          LatiasMega Latias    Dragon  ...          3       True    700
# 409  373    SalamenceMega Salamence    Dragon  ...          3      False    700
# 196  181      AmpharosMega Ampharos  Electric  ...          2      False    610
# 157  145                     Zapdos  Electric  ...          1       True    580
# ...

# %% [markdown]
# ###Confirm the type and the shape. With only 3 pokemon selected from all 18 categories, you will result in 54 pokemon total.

# %%
type(ultimate_showdown), ultimate_showdown.shape
# Out:
# (pandas.core.frame.DataFrame, (54, 13))

# %%
18 * 3
# Out:
# 54

# %%
# !ls
# Out:
# '\Downloads\pokemon_showdown.xlsx'   pokemonon_showdown.csv
#  output.xlsx			     pokemon_showdown.xlsx
#  pokemon_data.txt		     sample_data
#  pokemon_data.xlsx		    'sample_data\pokemon_showdown.xlsx'

# %% [markdown]
# ###Save it to a excel file or a csv file where you can send them your results! Rember once you type the code below, you NEED TO CLICK 'REFRESH' UNDER THE FILES TAB. Otherwise they won't appear!

# %%
ultimate_showdown.to_excel('pokemon_showdown.xlsx', index=False)

ultimate_showdown.to_csv('pokemon_showdown.csv', index=False, sep='\t')
